# %% [markdown]
# <a href="https://colab.research.google.com/github/BlockNotes-4515/ANIST-Summer-Research-Internship-2K26--/blob/main/GeoSpatial_Radiation_Mapping_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Build an Interactive Map with the Folium Library in Python and Google **Colab**
